# %% [raw]
# ---
# format:
#   html:
#     code-fold: false
# jupyter: python3
# ---

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-analytics-starter/blob/main/data_analytics.ipynb)

# %%
# load pre-existing tools available for data exploration

import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact # pre existing code for interaction

# %%
# Complete: Upload your downloaded CSV files to this Colab environment



# Do this by going over to the file icon on the left. Then, toward
# the top, find the file upload icon and upload your csv files.

# Complete: the CSV file must have the exact names data_survey.csv and data_analytics.csv

# %%
# data_analytics.csv

# Complete: update the column names to match the names you have in your csv file for data_analytics

# create a pandas dataframe
dfa = pd.read_csv(
    '/content/data_analytics.csv',
    sep=',',
    names = ['TODO', 'Replace', 'Your', 'Column names', 'Here', 'separated by commas as needed'],
    skiprows=1
)

# Display the first few rows of the DataFrame
print(dfa.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12242/3844069072.py in <cell line: 0>()
#       4
#       5 # create a pandas dataframe
# ----> 6 dfa = pd.read_csv(
#       7     '/content/data_analytics.csv',
#       8     sep=',',
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data_analytics.csv'

# %%
# data_survey.csv

# Complete: update the column names to match the names you have in your csv file for data_survey

# create a pandas dataframe
dfs = pd.read_csv(
    '/content/data_survey.csv',
    sep=',',
    names = ['TODO', 'Replace', 'Your', 'Column names', 'Here', 'separated by commas as needed'],
    skiprows=1
)

# Display the first few rows of the DataFrame
print(dfs.head())

# %%
# Complete: how many rows and columns are in the dataframe dfa?
# Complete: how many rows and columns are in the dataframe dfs?

# %%
# Analytics

# Complete: Do one or more explorations with dfa
# no interaction is required

# make a blank canvas

# make a title starting with 'Figure 1:' Fill in a relevant title
plt.title('TODO')

# plot
# ylabel
# xlabel
# ylim
# etc.

# reveal everything

# %%
# Survey

# Complete: Do one or more explorations with dfs
# no interaction is required

# make a blank canvas

# make a title starting with 'Figure 2:' Fill in a relevant title
plt.title('TODO')

# plot
# ylabel
# xlabel
# ylim
# etc.

# reveal everything

# %%
# When you are satisfied with your figures, write up your report in the file called report.qmd
